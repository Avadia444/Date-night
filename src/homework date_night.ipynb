# %% [markdown]
# # Date Night Movie

# %% [markdown]
# In this assignment we are going to use pandas to figure out - What's the best **date-night movie**?
#
# This assignment is going to use
# - Joining
# - Groupby
# - Sorting

# %%
import os
import pandas as pd

# %% [markdown]
# ##### Read in the movie data: `pd.read_table`

# %%
def get_movie_data():
    
    unames = ['user_id','gender','age','occupation','zip']
    users = pd.read_table(os.path.join('data','users.dat'), 
                          sep='::', header=None, names=unames, encoding='latin-1')
    
    rnames = ['user_id', 'movie_id', 'rating', 'timestamp']
    ratings = pd.read_table(os.path.join('data', 'ratings.dat'), 
                            sep='::', header=None, names=rnames, encoding='latin-1')
    
    mnames = ['movie_id', 'title','genres']
    movies = pd.read_table(os.path.join('data', 'movies.dat'), 
                           sep='::', header=None, names=mnames, encoding='latin-1')

    return users, ratings, movies

# %%
users, ratings, movies = get_movie_data()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17536\1407570117.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   users = pd.read_table(os.path.join('data','users.dat'),
# C:\Users\HP\AppData\Local\Temp\ipykernel_17536\1407570117.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   ratings = pd.read_table(os.path.join('data', 'ratings.dat'),
# C:\Users\HP\AppData\Local\Temp\ipykernel_17536\1407570117.py:12: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   movies = pd.read_table(os.path.join('data', 'movies.dat'),

# %%
print(users.head())
# Out:
#    user_id gender  age  occupation    zip
# 0        1      F    1          10  48067
# 1        2      M   56          16  70072
# 2        3      M   25          15  55117
# 3        4      M   45           7  02460
# 4        5      M   25          20  55455

# %%
print (ratings.head())
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
print (movies.head())
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %% [markdown]
# ##### Clean up the `movies`
#
# - Get the `year`
# - Shorten the `title`

# %%
tmp = movies.title.str.extract('(.*) \(([0-9]+)\)')
tmp.apply(lambda x:x[0] if len(x) > 0 else None)
tmp.apply(lambda x: x[0][:40] if len(x) > 0 else None)

# %%
movies['year'] = tmp[1]
movies['short_title'] = tmp[0]

# %%
print(movies.head())

# %% [markdown]
# ##### Join the tables with `pd.merge` (20 pts)

# %%
inner_join=pd.merge(users,ratings)
inner_join
# Out:
#          user_id gender  age  occupation    zip  movie_id  rating  timestamp
# 0              1      F    1          10  48067      1193       5  978300760
# 1              1      F    1          10  48067       661       3  978302109
# 2              1      F    1          10  48067       914       3  978301968
# 3              1      F    1          10  48067      3408       4  978300275
# 4              1      F    1          10  48067      2355       5  978824291
# ...          ...    ...  ...         ...    ...       ...     ...        ...
# 1000204     6040      M   25           6  11106      1091       1  956716541
# 1000205     6040      M   25           6  11106      1094       5  956704887
# 1000206     6040      M   25           6  11106       562       5  956704746
# 1000207     6040      M   25           6  11106      1096       4  956715648
# 1000208     6040      M   25           6  11106      1097       4  956715569
#
# [1000209 rows x 8 columns]

# %%
join2=pd.merge(inner_join,movies)
join2
# Out:
#          user_id gender  age  occupation    zip  movie_id  rating  timestamp  \
# 0              1      F    1          10  48067      1193       5  978300760
# 1              2      M   56          16  70072      1193       5  978298413
# 2             12      M   25          12  32793      1193       4  978220179
# 3             15      M   25           7  22903      1193       4  978199279
# 4             17      M   50           1  95350      1193       5  978158471
# ...          ...    ...  ...         ...    ...       ...     ...        ...
# 1000204     5949      M   18          17  47901      2198       5  958846401
# 1000205     5675      M   35          14  30030      2703       3  976029116
# 1000206     5780      M   18          17  92886      2845       1  958153068
# 1000207     5851      F   18          20  55410      3607       5  957756608
# 1000208     5938      M   25           1  35401      2909       4  957273353
#
#                                                title                genres
# 0             One Flew Over the Cuckoo's Nest (1975)                 Drama
# 1             One Flew Over the Cuckoo's Nest (1975)                 Drama
# 2             One Flew Over the Cuckoo's Nest (1975)                 Drama
# 3             One Flew Over the Cuckoo's Nest (1975)                 Drama
# 4             One Flew Over the Cuckoo's Nest (1975)                 Drama
# ...                                              ...                   ...
# 1000204                           Modulations (1998)           Documentary
# 1000205                        Broken Vessels (1998)                 Drama
# 1000206                            White Boys (1999)                 Drama
# 1000207                     One Little Indian (1973)  Comedy|Drama|Western
# 1000208  Five Wives, Three Secretaries and Me (1998)           Documentary
#
# [1000209 rows x 10 columns]

# %% [markdown]
# ##### What's the highest rated movie? (20 pts))

# %%
join2[join2.rating==join2.rating.max()]
# Out:
#          user_id gender  age  occupation    zip  movie_id  rating  timestamp  \
# 0              1      F    1          10  48067      1193       5  978300760
# 1              2      M   56          16  70072      1193       5  978298413
# 4             17      M   50           1  95350      1193       5  978158471
# 6             19      M    1          10  48073      1193       5  982730936
# 7             24      F   25           7  10023      1193       5  978136709
# ...          ...    ...  ...         ...    ...       ...     ...        ...
# 1000189     5532      M   25          17  27408       404       5  959619841
# 1000195     5313      M   56           0  55406      3656       5  960920392
# 1000199     5334      F   56          13  46140      3382       5  960796159
# 1000204     5949      M   18          17  47901      2198       5  958846401
# 1000207     5851      F   18          20  55410      3607       5  957756608
#
#                                                      title  \
# 0                   One Flew Over the Cuckoo's Nest (1975)
# 1                   One Flew Over the Cuckoo's Nest (1975)
# 4                   One Flew Over the Cuckoo's Nest (1975)
# 6                   One Flew Over the Cuckoo's Nest (1975)
# 7                   One Flew Over the Cuckoo's Nest (1975)
# ...                                                    ...
# 1000189  Brother Minister: The Assassination of Malcolm...
# 1000195                                       Lured (1947)
# 1000199                             Song of Freedom (1936)
# 1000204                                 Modulations (1998)
# 1000207                           One Little Indian (1973)
#
#                        genres
# 0                       Drama
# 1                       Drama
# 4                       Drama
# 6                       Drama
# 7                       Drama
# ...                       ...
# 1000189           Documentary
# 1000195                 Crime
# 1000199                 Drama
# 1000204           Documentary
# 1000207  Comedy|Drama|Western
#
# [226310 rows x 10 columns]

# %%
join2.rating.max()
# Out:
# 5

# %% [raw]
# ## What is a good rated movie for date night? (60 pts)
#
# - Hint - highly rated movie by
#     - both partners (might be the same gender or not),
#     - based on genre preferences,
#     - age group can also be combined

# %%
join2[join2.gender=='M'][join2.rating==join2.rating.max()]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17536\3957762480.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   join2[join2.gender=='M'][join2.rating==join2.rating.max()]
#          user_id gender  age  occupation    zip  movie_id  rating  timestamp  \
# 1              2      M   56          16  70072      1193       5  978298413
# 4             17      M   50           1  95350      1193       5  978158471
# 6             19      M    1          10  48073      1193       5  982730936
# 9             33      M   45           3  55421      1193       5  978557765
# 10            39      M   18           4  61820      1193       5  978043535
# ...          ...    ...  ...         ...    ...       ...     ...        ...
# 1000168     4635      M   18           4  94703       439       5  964037004
# 1000172     4751      M   50          15  02474      2480       5  963187849
# 1000189     5532      M   25          17  27408       404       5  959619841
# 1000195     5313      M   56           0  55406      3656       5  960920392
# 1000204     5949      M   18          17  47901      2198       5  958846401
#
#                                                      title       genres
# 1                   One Flew Over the Cuckoo's Nest (1975)        Drama
# 4                   One Flew Over the Cuckoo's Nest (1975)        Drama
# 6                   One Flew Over the Cuckoo's Nest (1975)        Drama
# 9                   One Flew Over the Cuckoo's Nest (1975)        Drama
# 10                  One Flew Over the Cuckoo's Nest (1975)        Drama
# ...                                                    ...          ...
# 1000168                              Dangerous Game (1993)        Drama
# 1000172              Dry Cleaning (Nettoyage à sec) (1997)        Drama
# 1000189  Brother Minister: The Assassination of Malcolm...  Documentary
# 1000195                                       Lured (1947)        Crime
# 1000204                                 Modulations (1998)  Documentary
#
# [167764 rows x 10 columns]

# %%
join2[join2.gender=='F'][join2.rating==join2.rating.max()]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17536\1072484607.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   join2[join2.gender=='F'][join2.rating==join2.rating.max()]
#          user_id gender  age  occupation    zip  movie_id  rating  timestamp  \
# 0              1      F    1          10  48067      1193       5  978300760
# 7             24      F   25           7  10023      1193       5  978136709
# 22            81      F   25           0  60640      1193       5  977785864
# 23            88      F   45           1  02476      1193       5  977694161
# 24            89      F   56           9  85749      1193       5  977683596
# ...          ...    ...  ...         ...    ...       ...     ...        ...
# 1000042     2885      F   18           1  80302      3881       5  972452947
# 1000082     5423      F   50           5  60714      3609       5  960148322
# 1000176     4790      F   25           2  94133      2309       5  963105678
# 1000199     5334      F   56          13  46140      3382       5  960796159
# 1000207     5851      F   18          20  55410      3607       5  957756608
#
#                                               title                genres
# 0            One Flew Over the Cuckoo's Nest (1975)                 Drama
# 7            One Flew Over the Cuckoo's Nest (1975)                 Drama
# 22           One Flew Over the Cuckoo's Nest (1975)                 Drama
# 23           One Flew Over the Cuckoo's Nest (1975)                 Drama
# 24           One Flew Over the Cuckoo's Nest (1975)                 Drama
# ...                                             ...                   ...
# 1000042                    Bittersweet Motel (2000)           Documentary
# 1000082                     Regret to Inform (1998)           Documentary
# 1000176  Inheritors, The (Die Siebtelbauern) (1998)                 Drama
# 1000199                      Song of Freedom (1936)                 Drama
# 1000207                    One Little Indian (1973)  Comedy|Drama|Western
#
# [58546 rows x 10 columns]

# %%
pd.cut(join2.age, [0,14,35,57], labels=['child','middle-aged','old',])
# Out:
# 0                child
# 1                  old
# 2          middle-aged
# 3          middle-aged
# 4                  old
#               ...
# 1000204    middle-aged
# 1000205    middle-aged
# 1000206    middle-aged
# 1000207    middle-aged
# 1000208    middle-aged
# Name: age, Length: 1000209, dtype: category
# Categories (3, object): ['child' < 'middle-aged' < 'old']

# %%
join2.age.value_counts()
# Out:
# 25    395556
# 35    199003
# 18    183536
# 45     83633
# 50     72490
# 56     38780
# 1      27211
# Name: age, dtype: int64

# %%
join2['age_cat']=a

# %%
join2
# Out:
#          user_id gender  age  occupation    zip  movie_id  rating  timestamp  \
# 0              1      F    1          10  48067      1193       5  978300760
# 1              2      M   56          16  70072      1193       5  978298413
# 2             12      M   25          12  32793      1193       4  978220179
# 3             15      M   25           7  22903      1193       4  978199279
# 4             17      M   50           1  95350      1193       5  978158471
# ...          ...    ...  ...         ...    ...       ...     ...        ...
# 1000204     5949      M   18          17  47901      2198       5  958846401
# 1000205     5675      M   35          14  30030      2703       3  976029116
# 1000206     5780      M   18          17  92886      2845       1  958153068
# 1000207     5851      F   18          20  55410      3607       5  957756608
# 1000208     5938      M   25           1  35401      2909       4  957273353
#
#                                                title                genres
# 0             One Flew Over the Cuckoo's Nest (1975)                 Drama
# 1             One Flew Over the Cuckoo's Nest (1975)                 Drama
# 2             One Flew Over the Cuckoo's Nest (1975)                 Drama
# 3             One Flew Over the Cuckoo's Nest (1975)                 Drama
# 4             One Flew Over the Cuckoo's Nest (1975)                 Drama
# ...                                              ...                   ...
# 1000204                           Modulations (1998)           Documentary
# 1000205                        Broken Vessels (1998)                 Drama
# 1000206                            White Boys (1999)                 Drama
# 1000207                     One Little Indian (1973)  Comedy|Drama|Western
# 1000208  Five Wives, Three Secretaries and Me (1998)           Documentary
#
# [1000209 rows x 10 columns]
